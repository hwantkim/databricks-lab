# %% [markdown]
# ## 설정 파일
#
# 데모를 다른 카탈로그에서 실행하려면 아래에서 카탈로그와 스키마를 변경하세요.
#
# <!-- Collect usage data (view). Remove it to disable collection or disable tracker during installation. View README for more details.  -->
# <img width="1px" src="https://ppxrzfxige.execute-api.us-west-2.amazonaws.com/v1/analytics?category=data-science&org_id=601859075515029&notebook=%2Fconfig&demo_name=ai-agent&event=VIEW&path=%2F_dbdemos%2Fdata-science%2Fai-agent%2Fconfig&version=1">

# %%
# 참고: 여기서 카탈로그를 변경하는 것은 권장하지 않습니다. SDP 파이프라인 및 대시보드와 같은 모든 데모 리소스에는 영향을 주지 않기 때문입니다.
# 대신 dbdemos.install("lakehouse-retail-c360", catalog="..", schema="...")를 사용하여 특정 카탈로그와 스키마로 데모를 재설치하세요.

catalog = "main"
schema = dbName = db = "dbdemos_ai_agent"

volume_name = "raw_data"
VECTOR_SEARCH_ENDPOINT_NAME="dbdemos_vs_endpoint"

MODEL_NAME = "dbdemos_ai_agent_demo"
ENDPOINT_NAME = f'{MODEL_NAME}_{catalog}_{db}'[:60]

# 이 모델은 반드시 도구(tool) 기능이 활성화된 모델이어야 합니다
LLM_ENDPOINT_NAME = 'databricks-gemma-3-12b'
