# %% [markdown]
# # AI 에이전트의 비즈니스 영향을 Databricks Lakeflow, AI/BI Dashboard, Genie로 측정하세요!
#
# 새로운 AI 프로젝트를 배포하는 것도 좋지만, 궁극적으로는 에이전트가 비즈니스에 어떤 영향을 미치는지 추적하고 싶을 것입니다.
#
# 일반적으로 고객 지원 어시스턴트는 다음과 같은 효과를 가져야 합니다:
#
# - 문제 해결 시간 단축
# - 고객 만족도 향상
# - 비즈니스 성과 증대
# - 지원 팀이 더 높은 품질의 상호작용으로 더 많은 일을 할 수 있도록 지원...
#
# Databricks를 사용하면 이러한 모든 지표를 추적할 수 있습니다: Lakeflow Connect 또는 다른 수집 방법을 통해 CRM이나 티켓 시스템을 연결하고, 필요한 경우 데이터를 준비 및 변환한 후, 비즈니스 중심의 대시보드를 배포하고, Databricks Genie를 사용하여 데이터에 대한 후속 질문을 할 수 있습니다!
#
# <img src="https://github.com/databricks-demos/dbdemos-resources/blob/main/images/product/ai-agent/customer-support-dashboard.png?raw=true" width="900px">

# %% [markdown]
# ## AI/BI 고객 지원 설정을 시도해보고 싶으신가요?
#
# 다음 셀을 실행하여 dbdemos 고객 지원을 설치하세요:

# %%
# dbdemos 패키지 설치 및 Python 커널 재시작
# %pip install dbdemos -U
# %restart_python

# %%
# dbdemos를 사용하여 AI/BI 고객 지원 데모 설치
import dbdemos
dbdemos.install('aibi-customer-support', catalog='main', schema='dbdemos_aibi_customer_support')
